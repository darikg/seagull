# %%
import pyvista as pv

file = r"C:\Users\14436\Documents\python\cgal\Data\data\meshes\elephant.off"
m = pv.read(file)
m.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x15CBEFFAF70>
